# %%
import pandas as pd
import yfinance as yf

# %%
data = yf.download(["GOOG","KPITTECH.NS"], period="5Y")
data
# Out:
# [*********************100%%**********************]  2 of 2 completed
#              Adj Close                    Close                     High  \
#                   GOOG  KPITTECH.NS        GOOG  KPITTECH.NS        GOOG
# Date
# 2019-01-28   53.504002          NaN   53.504002          NaN   54.150002
# 2019-01-29   53.030998          NaN   53.030998          NaN   53.757500
# 2019-01-30   54.452999          NaN   54.452999          NaN   54.549999
# 2019-01-31   55.818501          NaN   55.818501          NaN   55.866501
# 2019-02-01   55.537498          NaN   55.537498          NaN   56.250000
# ...                ...          ...         ...          ...         ...
# 2024-01-22  147.710007  1547.800049  147.710007  1547.800049  150.014999
# 2024-01-23  148.679993  1501.500000  148.679993  1501.500000  148.860001
# 2024-01-24  150.350006  1506.550049  150.350006  1506.550049  151.570007
# 2024-01-25  153.639999  1415.449951  153.639999  1415.449951  154.759995
# ...

# %%
type(data.head(1).index.year[0])
# Out:
# numpy.int32

# %%
data.shape
# Out:
# (1296, 12)

# %%
goog_df = data.xs("GOOG", level=1, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1296 entries, 2019-01-28 to 2024-01-26
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, GOOG)         1259 non-null   float64
#  1   (Adj Close, KPITTECH.NS)  1181 non-null   float64
#  2   (Close, GOOG)             1259 non-null   float64
#  3   (Close, KPITTECH.NS)      1181 non-null   float64
#  4   (High, GOOG)              1259 non-null   float64
#  5   (High, KPITTECH.NS)       1181 non-null   float64
#  6   (Low, GOOG)               1259 non-null   float64
#  7   (Low, KPITTECH.NS)        1181 non-null   float64
#  8   (Open, GOOG)              1259 non-null   float64
#  9   (Open, KPITTECH.NS)       1181 non-null   float64
#  10  (Volume, GOOG)            1259 non-null   float64
#  11  (Volume, KPITTECH.NS)     1181 non-null   float64
# dtypes: float64(12)
# memory usage: 131.6 KB

# %%
goog_df.sample(2)
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2019-05-08   58.313499   58.313499   59.021198   58.286999   58.600498
# 2023-08-29  135.490005  135.490005  137.294998  132.979996  132.998001
#
#                 Volume
# Date
# 2019-05-08  26186000.0
# 2023-08-29  30803300.0

# %%
import plotly.express as pe

# %%
pe.scatter(x="Open", y="Close", data_frame=goog_df, color=None)
