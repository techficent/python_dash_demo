# %%
import pandas as pd
import yfinance as yf

# %%
help(yf.Ticker)
# Out:
# Help on class Ticker in module yfinance.ticker:
#
# class Ticker(yfinance.base.TickerBase)
#  |  Ticker(ticker, session=None)
#  |
#  |  Method resolution order:
#  |      Ticker
#  |      yfinance.base.TickerBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, ticker, session=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  option_chain(self, date=None, proxy=None, tz=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  actions
#  |
#  |  analyst_price_target
#  |
#  |  balance_sheet
#  |
#  |  balancesheet
#  |
#  |  calendar
#  |
#  |  capital_gains
#  |
#  |  cash_flow
#  |
#  |  cashflow
#  |
#  |  dividends
#  |
#  |  earnings
#  |
#  |  earnings_dates
#  |
#  |  earnings_forecasts
#  |
#  |  earnings_trend
#  |
#  |  fast_info
#  |
#  |  financials
#  |
# ...

# %%
data = yf.download(["GOOG","KPITTECH.NS"], period="5Y")
data
# Out:
# [*********************100%%**********************]  2 of 2 completed
#              Adj Close                    Close                     High  \
#                   GOOG  KPITTECH.NS        GOOG  KPITTECH.NS        GOOG
# Date
# 2019-01-07   53.419498          NaN   53.419498          NaN   53.700001
# 2019-01-08   53.813999          NaN   53.813999          NaN   54.228001
# 2019-01-09   53.733002          NaN   53.733002          NaN   54.131500
# 2019-01-10   53.516499          NaN   53.516499          NaN   53.557499
# 2019-01-11   52.859501          NaN   52.859501          NaN   53.188751
# ...                ...          ...         ...          ...         ...
# 2024-01-01         NaN  1490.500000         NaN  1490.500000         NaN
# 2024-01-02  139.559998  1467.849976  139.559998  1467.849976  140.615005
# 2024-01-03  140.360001  1462.699951  140.360001  1462.699951  141.089996
# 2024-01-04  138.039993  1472.400024  138.039993  1472.400024  140.634995
# ...

# %%
data.shape
# Out:
# (1295, 12)

# %%
data.xs("GOOG", level=1, axis=1)
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2019-01-07   53.419498   53.419498   53.700001   52.737999   53.575001
# 2019-01-08   53.813999   53.813999   54.228001   53.026501   53.805500
# 2019-01-09   53.733002   53.733002   54.131500   53.320000   54.082500
# 2019-01-10   53.516499   53.516499   53.557499   52.885502   53.382999
# 2019-01-11   52.859501   52.859501   53.188751   52.424000   53.159000
# ...                ...         ...         ...         ...         ...
# 2024-01-01         NaN         NaN         NaN         NaN         NaN
# 2024-01-02  139.559998  139.559998  140.615005  137.740005  139.600006
# 2024-01-03  140.360001  140.360001  141.089996  138.429993  138.600006
# 2024-01-04  138.039993  138.039993  140.634995  138.009995  139.850006
# 2024-01-05  137.389999  137.389999  138.809998  136.850006  138.352005
#
#                 Volume
# Date
# 2019-01-07  39638000.0
# 2019-01-08  35298000.0
# 2019-01-09  23986000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1295 entries, 2019-01-07 to 2024-01-05
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, GOOG)         1259 non-null   float64
#  1   (Adj Close, KPITTECH.NS)  1167 non-null   float64
#  2   (Close, GOOG)             1259 non-null   float64
#  3   (Close, KPITTECH.NS)      1167 non-null   float64
#  4   (High, GOOG)              1259 non-null   float64
#  5   (High, KPITTECH.NS)       1167 non-null   float64
#  6   (Low, GOOG)               1259 non-null   float64
#  7   (Low, KPITTECH.NS)        1167 non-null   float64
#  8   (Open, GOOG)              1259 non-null   float64
#  9   (Open, KPITTECH.NS)       1167 non-null   float64
#  10  (Volume, GOOG)            1259 non-null   float64
#  11  (Volume, KPITTECH.NS)     1167 non-null   float64
# dtypes: float64(12)
# memory usage: 131.5 KB
